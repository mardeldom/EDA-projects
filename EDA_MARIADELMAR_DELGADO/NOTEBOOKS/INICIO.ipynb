# %%
import pandas as pd

# %%
prueba= pd.read_csv("2020-12-21-csv_exportSurveyQuestion-LGBTI-AllSubset-0--All-DEXavoid_hands-EN-0--All.csv",delimiter= "\t", encoding="latin1", skiprows=13)
prueba
# Out:
#     CountryCode   question_code  \
# 0       Austria  DEXavoid_hands
# 1       Austria  DEXavoid_hands
# 2       Austria  DEXavoid_hands
# 3       Austria  DEXavoid_hands
# 4       Austria  DEXavoid_hands
# ..          ...             ...
# 150      Serbia  DEXavoid_hands
# 151      Serbia  DEXavoid_hands
# 152      Serbia  DEXavoid_hands
# 153      Serbia  DEXavoid_hands
# 154      Serbia  DEXavoid_hands
#
#                                         question_label target_group subset  \
# 0    Avoid holding hands in public with same-sex pa...          All    All
# 1    Avoid holding hands in public with same-sex pa...          All    All
# 2    Avoid holding hands in public with same-sex pa...          All    All
# 3    Avoid holding hands in public with same-sex pa...          All    All
# 4    Avoid holding hands in public with same-sex pa...          All    All
# ..                                                 ...          ...    ...
# ...

# %%
import csv
with open("2020-12-21-csv_exportSurveyQuestion-LGBTI-AllSubset-0--All-DEXavoid_hands-EN-0--All.csv", encoding='latin1') as f: 
    reader = csv.reader(f, delimiter= "\t")
    reader = csv.reader(f, delimiter= ",")
    #reader = csv.reader(f, delimiter= " "" ")
    reader_data = pd.DataFrame(f)
    reader_data
    """for row in reader:
        print(row)"""

# %%
import csv
with open('2020-12-21-csv_exportSurveyQuestion-LGBTI-AllSubset-0--All-DEXavoid_hands-EN-0--All.csv', encoding='latin1') as f:
    for row in csv.reader(f, skipinitialspace=True):
       print(''.join(row))
    prueba = pd.read_csv(f, skiprows=13, header= None)
    prueba
# Out:
#  in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Rarely"	36	""
# Germany	"DEXavoid_hands"	"Avoid holding hands in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Never"	19	""
# Germany	"DEXavoid_hands"	"Avoid holding hands in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Dont know"	0	""
# Denmark	"DEXavoid_hands"	"Avoid holding hands in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Always"	16	""
# Denmark	"DEXavoid_hands"	"Avoid holding hands in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Often"	28	""
# Denmark	"DEXavoid_hands"	"Avoid holding hands in public with same-sex partner for fear of being assaultedthreatened or harassed"	"All"	"All"	"Rarely"	34	""
# ...

# %%
import csv
with open('2020-12-21-csv_exportSurveyQuestion-LGBTI-AllSubset-0--All-DEXavoid_hands-EN-0--All.csv') as f:
    for row in csv.reader(f, delimiter=' ', skipinitialspace=True):
       print('|'.join(row))
    prueba = pd.read_csv(f)
    prueba
# Out:
# "Never"	19	""
# Germany	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Dont|know"	0	""
# Denmark	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Always"	16	""
# Denmark	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Often"	28	""
# Denmark	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Rarely"	34	""
# Denmark	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Never"	22	""
# Denmark	"DEXavoid_hands"	"Avoid|holding|hands|in|public|with|same-sex|partner|for|fear|of|being|assaulted,|threatened|or|harassed"	"All"	"All"	"Dont|know"	1	"‡"
# ...

# %%
prueba = pd.read_csv(f)
prueba
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-50ef8777fedb> in <module>
# ----> 1 prueba = pd.read_csv(f)
#       2 prueba
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...
